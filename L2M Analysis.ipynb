# %%
import json
from datetime import datetime
import pandas as pd

# %%
import requests
url = "https://official.nba.com/l2m/json/0022200741.json"
payload = ""
response = requests.request("GET", url, data=payload) #headers=headers)
# print(response.json())

# %%
gameData = response.json()
# print('Home errors in favor: ' + str(gameData["stats"][1]["home"]))
# print('Away errors in favor: ' + str(gameData["stats"][1]["away"]))

# %%
file = open('l2m_GameId.json')
games = json.load(file)
# print(games[0]["gameId"])

# %%
# print(games)

# %%
gameData = []
for game in games:
    url = f'https://official.nba.com/l2m/json/{game["gameId"]}.json' # 0022200677
    payload = ""
    response = requests.request("GET", url, data=payload) #headers=headers)
    #print(response)
    if response.status_code == 200: 
        gameData.append(response.json())
#     else: 
#         print(game["gameId"])
#print(gameData)

# %%
# gameData = []
# url = f'https://official.nba.com/l2m/json/0022200677.json' #{game["gameId"]}
# payload = ""
# response = requests.request("GET", url, data=payload)#headers=headers)
# #print(response)
# if response.status_code == 200: 
#     gameData.append(response.json())
# #     else: 
# #         print(game["gameId"])
# #print(gameData)

# %%
# gameData[0]

# %%
# gameData

# %%
timestamps = []
CC = 0
CNC = 0
IC = 0
INC = 0
for data in gameData:
    times = data["l2m"] 
    #print(times)
    for time in times:
        timestamps = time['PCTime'][:5]
        time_left = int(timestamps[:2])*60 + int(timestamps[3:5])
        call_rate = time['CallRatingName']
        if time_left <= 120 and time_left > 30:
            print(timestamps, str(time_left) + ' secs', call_rate)
            if call_rate == "CC":
                CC = CC + 1
            elif call_rate == "CNC":
                CNC = CNC + 1                
            elif call_rate == "IC":
                IC = IC + 1
            else:
                INC = INC + 1
                    
print("Correct Calls: " + str(CC/len(games)))
print("Correct No Calls: " + str(CNC/len(games)))
print("Incorrect Calls: " + str(IC/len(games)))
print("Incorrect No Calls: " + str(INC/len(games)))
# Out:
# 01:43 103 secs CNC
# 01:31 91 secs CNC
# 01:29 89 secs CNC
# 01:27 87 secs INC
# 01:26 86 secs CNC
# 01:22 82 secs CNC
# 01:12 72 secs CNC
# 01:02 62 secs CNC
# 00:59 59 secs CC
# 00:51 51 secs CNC
# 00:50 50 secs CNC
# 00:41 41 secs CNC
# 00:39 39 secs CNC
# 00:35 35 secs CNC
# 01:54 114 secs CNC
# 01:32 92 secs CNC
# 01:31 91 secs CNC
# 01:29 89 secs CNC
# 01:25 85 secs CNC
# 01:24 84 secs CNC
# 01:14 74 secs CNC
# 01:04 64 secs CNC
# 01:01 61 secs CNC
# 00:51 51 secs CNC
# 00:37 37 secs CNC
# 00:36 36 secs CNC
# 00:34 34 secs CNC
# 00:31 31 secs CC
# 00:31 31 secs CNC
# 00:31 31 secs CNC
# 02:00 120 secs CNC
# 01:54 114 secs CNC
# 01:53 113 secs INC
# 01:50 110 secs CNC
# 01:48 108 secs CC
# 01:40 100 secs CNC
# 01:31 91 secs CNC
# 01:30 90 secs CC
# 01:22 82 secs INC
# 01:17 77 secs CC
# 01:07 67 secs CNC
# 01:07 67 secs CNC
# 00:56 56 secs CNC
# 00:35 35 secs CC
# 01:57 117 secs CNC
# 01:53 113 secs CNC
# 01:52 112 secs CNC
# 01:47 107 secs CNC
# 01:46 106 secs CC
# ...

# %%
# timestamps = []
# CC = 0
# CNC = 0
# IC = 0
# INC = 0
# for data in gameData:
#     times = data["l2m"] 
#     #print(times)
#     for time in times:
#         timestamps = time['PCTime'][:5]
#         time_left = int(timestamps[:2])*60 + int(timestamps[3:5])
#         call_rate = time['CallRatingName']
#         if time_left <= 120 and time_left > 90:
#             print(timestamps, str(time_left) + ' secs', call_rate)
#             if call_rate == "CC":
#                 CC = CC + 1
#             elif call_rate == "CNC":
#                 CNC = CNC + 1                
#             elif call_rate == "IC":
#                 IC = IC + 1
#             else:
#                 INC = INC + 1
                    
# print("Correct Calls: " + str(CC/len(games)))
# print("Correct No Calls: " + str(CNC/len(games)))
# print("Incorrect Calls: " + str(IC/len(games)))
# print("Incorrect No Calls: " + str(INC/len(games)))

# %%
# timestamps = []
# CC = 0
# CNC = 0
# IC = 0
# INC = 0
# for data in gameData:
#     times = data["l2m"] 
#     #print(times)
#     for time in times:
#         timestamps = time['PCTime'][:5]
#         time_left = int(timestamps[:2])*60 + int(timestamps[3:5])
#         call_rate = time['CallRatingName']
#         if time_left <= 90 and time_left > 60:
#             print(timestamps, str(time_left) + ' secs', call_rate)
#             if call_rate == "CC":
#                 CC = CC + 1
#             elif call_rate == "CNC":
#                 CNC = CNC + 1                
#             elif call_rate == "IC":
#                 IC = IC + 1
#             else:
#                 INC = INC + 1
                    
# print("Correct Calls: " + str(CC/len(games)))
# print("Correct No Calls: " + str(CNC/len(games)))
# print("Incorrect Calls: " + str(IC/len(games)))
# print("Incorrect No Calls: " + str(INC/len(games)))

# %%
# timestamps = []
# CC = 0
# CNC = 0
# IC = 0
# INC = 0
# for data in gameData:
#     times = data["l2m"] 
#     #print(times)
#     for time in times:
#         timestamps = time['PCTime'][:5]
#         time_left = int(timestamps[:2])*60 + int(timestamps[3:5])
#         call_rate = time['CallRatingName']
#         if time_left <= 60 and time_left > 30:
#             print(timestamps, str(time_left) + ' secs', call_rate)
#             if call_rate == "CC":
#                 CC = CC + 1
#             elif call_rate == "CNC":
#                 CNC = CNC + 1                
#             elif call_rate == "IC":
#                 IC = IC + 1
#             else:
#                 INC = INC + 1
                    
# print("Correct Calls: " + str(CC/len(games)))
# print("Correct No Calls: " + str(CNC/len(games)))
# print("Incorrect Calls: " + str(IC/len(games)))
# print("Incorrect No Calls: " + str(INC/len(games)))

# %%
print(len(games))
# Out:
# 318

# %%
timestamps = []
CC = 0
CNC = 0
IC = 0
INC = 0
for data in gameData:
    times = data["l2m"] 
    #print(times)
    for time in times:
        timestamps = time['PCTime'][:5]
        time_left = int(timestamps[:2])*60 + int(timestamps[3:5])
        call_rate = time['CallRatingName']
        if time_left <= 30:
            print(timestamps, str(time_left) + ' secs', call_rate)
            if call_rate == "CC":
                CC = CC + 1
            elif call_rate == "CNC":
                CNC = CNC + 1                
            elif call_rate == "IC":
                IC = IC + 1
            else:
                INC = INC + 1
                    
print("Correct Calls: " + str(CC/len(games)))
print("Correct No Calls: " + str(CNC/len(games)))
print("Incorrect Calls: " + str(IC/len(games)))
print("Incorrect No Calls: " + str(INC/len(games)))
# Out:
# 00:17 17 secs CNC
# 00:17 17 secs CNC
# 00:14 14 secs CNC
# 00:11 11 secs CNC
# 00:10 10 secs CNC
# 00:05 5 secs IC
# 00:04 4 secs CC
# 00:03 3 secs INC
# 00:22 22 secs CNC
# 00:14 14 secs CC
# 00:11 11 secs CNC
# 00:08 8 secs CC
# 00:03 3 secs CNC
# 00:19 19 secs IC
# 00:16 16 secs CC
# 00:15 15 secs CNC
# 00:13 13 secs CNC
# 00:10 10 secs CC
# 00:10 10 secs CNC
# 00:07 7 secs CC
# 00:04 4 secs CC
# 00:03 3 secs CC
# 00:02 2 secs CNC
# 00:00 0 secs CC
# 00:00 0 secs CNC
# 00:28 28 secs CC
# 00:09 9 secs CNC
# 00:08 8 secs CNC
# 00:00 0 secs CC
# 00:09 9 secs CC
# 00:07 7 secs INC
# 00:04 4 secs CC
# 00:03 3 secs CC
# 00:03 3 secs INC
# 00:21 21 secs CNC
# 00:15 15 secs CNC
# 00:14 14 secs CC
# 00:10 10 secs CC
# 00:08 8 secs CC
# 00:23 23 secs CNC
# 00:14 14 secs CNC
# 00:11 11 secs CNC
# 00:06 6 secs CNC
# 00:03 3 secs CNC
# 00:02 2 secs CNC
# 00:22 22 secs CC
# 00:22 22 secs INC
# 00:21 21 secs CNC
# 00:18 18 secs CC
# 00:16 16 secs CNC
# 00:14 14 secs CC
# 00:11 11 secs CC
# ...

# %%
# timestamps = []
# CC = 0
# CNC = 0
# IC = 0
# INC = 0
# for data in gameData:
#     times = data["l2m"] 
#     #print(times)
#     for time in times:
#         timestamps = time['PCTime'][:5]
#         time_left = int(timestamps[:2])*60 + int(timestamps[3:5])
#         call_rate = time['CallRatingName']
#         if time_left <= 120:
#             print(timestamps, str(time_left) + ' secs', call_rate)
#             if call_rate == "CC":
#                 CC = CC + 1
#             elif call_rate == "CNC":
#                 CNC = CNC + 1                
#             elif call_rate == "IC":
#                 IC = IC + 1
#             else:
#                 INC = INC + 1
                    
# print("Correct Calls: " + str(CC/len(games)))
# print("Correct No Calls: " + str(CNC/len(games)))
# print("Incorrect Calls: " + str(IC/len(games)))
# print("Incorrect No Calls: " + str(INC/len(games)))

# %%
#home vs away errors in favor
home_errors = 0
away_errors = 0
for game in gameData:
    home_errors = home_errors + game["stats"][1]["home"]
    away_errors = away_errors + game["stats"][1]["away"]
print('Home errors in favor: ' + str(home_errors))
print('Away errors in favor: ' + str(away_errors))
# Out:
# Home errors in favor: 244
# Away errors in favor: 226

# %%
# gameData[0]

# %%
#Errors at home
error_in_favor = 0
error_against = 0
for game in gameData:
    home_team = game["game"][0]["Home_team"]
    #print(home_team)
    home_errors = game["stats"][1]["home"]
    away_errors = game["stats"][1]["away"]
    if home_team == 'Lakers':
        error_in_favor = error_in_favor + home_errors
        error_against = error_against + away_errors
print("Laker specific errors at home: ")
print("Errors in favor: " + str(error_in_favor))
print("Errors against: " + str(error_against))
# Out:
# Laker specific errors at home:
# Errors in favor: 16
# Errors against: 12

# %%
#Errors on the road
error_in_favor = 0
error_against = 0
for game in gameData:
    away_team = game["game"][0]["Away_team"]
    #print(home_team)
    home_errors = game["stats"][1]["home"]
    away_errors = game["stats"][1]["away"]
    if away_team == 'Lakers':
        error_in_favor = error_in_favor + away_errors
        error_against = error_against + home_errors
print("Laker specific errors on the road: ")
print("Errors in favor: " + str(error_in_favor))
print("Errors against: " + str(error_against))
# Out:
# Laker specific errors on the road:
# Errors in favor: 7
# Errors against: 5

# %%
our_games = pd.read_csv("Laker_games.csv")
laker_games = our_games['gameId'].tolist()
laker_games = ["00" + str(game) if str(game).isdigit() else str(game) for game in laker_games]
print(our_games)
print(laker_games)
# Out:
#       gameId
# 0   22200037
# 1   22200117
# 2   22200183
# 3   22200308
# 4   22200331
# 5   22200382
# 6   22200396
# 7   22200413
# 8   22200451
# 9   22200492
# 10  22200574
# 11  22200595
# 12  22200630
# 13  22200655
# 14  22200664
# 15  22200677
# 16  22200690
# 17  22200749
# 18  22200765
# 19  22200778
# 20  22200821
# ['0022200037', '0022200117', '0022200183', '0022200308', '0022200331', '0022200382', '0022200396', '0022200413', '0022200451', '0022200492', '0022200574', '0022200595', '0022200630', '0022200655', '0022200664', '0022200677', '0022200690', '0022200749', '0022200765', '0022200778', '0022200821']

# %%
gameData = []
for game in laker_games:
    url = f'https://official.nba.com/l2m/json/{game}.json' 
    payload = ""
    response = requests.request("GET", url, data=payload) #headers=headers)
    if response.status_code == 200: 
        gameData.append(response.json())
    else:
        print(f'Request failed with status code: {response.status_code}')
        print(f'Error message: {response.text}')
print(laker_games)
print(gameData)
# Out:
# ['0022200037', '0022200117', '0022200183', '0022200308', '0022200331', '0022200382', '0022200396', '0022200413', '0022200451', '0022200492', '0022200574', '0022200595', '0022200630', '0022200655', '0022200664', '0022200677', '0022200690', '0022200749', '0022200765', '0022200778', '0022200821']
# ...

# %%
players = pd.read_csv("Lakers.csv")
player_names = players['player'].tolist()
timestamps = []
CC = 0
CNC = 0
IC = 0
INC = 0
for data in gameData:
    times = data["l2m"] 
    #print(times)
    for time in times:
        timestamps = time['PCTime'][:5]
        time_left = int(timestamps[:2])*60 + int(timestamps[3:5])
        call_rate = time['CallRatingName']
        dp = time['DP']
        cp = time['CP']
        action = time['Comment']
        for player in player_names:
            if player == dp or dp == 'Lakers':
                if time_left <= 120 and time_left > 30:
                    print(timestamps, str(time_left) + ' secs', 'CP: ' + cp, 'DP: ' + dp, call_rate)
                    if call_rate == "CC":
                        CC = CC + 1
                    elif call_rate == "CNC":
                        CNC = CNC + 1                
                    elif call_rate == "IC":
                        IC = IC + 1
                    else:
                        INC = INC + 1
                    break
        else:
            continue
                    
print("Correct Calls: " + str(CC))
print("Correct No Calls: " + str(CNC))
print("Incorrect Calls: " + str(IC))
print("Incorrect No Calls: " + str(INC))
# Out:
# 01:57 117 secs CP: Josh Hart DP: LeBron James CNC
# 01:54 114 secs CP: Jusuf Nurkic DP: Lonnie Walker IV CNC
# 01:31 91 secs CP: Damian Lillard DP: Patrick Beverley CNC
# 01:29 89 secs CP: Jusuf Nurkic DP: Anthony Davis CNC
# 00:55 55 secs CP: Jerami Grant DP: LeBron James CNC
# 00:39 39 secs CP: Jusuf Nurkic DP: Lonnie Walker IV CNC
# 02:00 120 secs CP: Larry Nance Jr. DP: Austin Reaves CNC
# 01:59 119 secs CP: Devonte' Graham DP: Austin Reaves CNC
# 01:55 115 secs CP: Devonte' Graham DP: Anthony Davis CNC
# 01:55 115 secs CP: Trey Murphy III DP: Anthony Davis CNC
# 01:53 113 secs CP: Naji Marshall DP: LeBron James CNC
# 01:53 113 secs CP: Trey Murphy III DP: Lakers CC
# 01:43 103 secs CP: Zion Williamson DP: Lakers INC
# 01:42 102 secs CP: Larry Nance Jr. DP: LeBron James CC
# 01:27 87 secs CP: Larry Nance Jr. DP: Austin Reaves CC
# 01:13 73 secs CP: CJ McCollum DP: Patrick Beverley CNC
# 00:55 55 secs CP: Naji Marshall DP: LeBron James CNC
# ...

# %%
# players = pd.read_csv("Lakers.csv")
# player_names = players['player'].tolist()
# timestamps = []
# CC = 0
# CNC = 0
# IC = 0
# INC = 0
# for data in gameData:
#     times = data["l2m"] 
#     #print(times)
#     for time in times:
#         timestamps = time['PCTime'][:5]
#         time_left = int(timestamps[:2])*60 + int(timestamps[3:5])
#         call_rate = time['CallRatingName']
#         dp = time['DP']
#         cp = time['CP']
#         action = time['Comment']
#         for player in player_names:
#             if player == dp or dp == 'Lakers':
#                 if time_left <= 120 and time_left > 90:
#                     print(timestamps, str(time_left) + ' secs', 'CP: ' + cp, 'DP: ' + dp, call_rate)
#                     if call_rate == "CC":
#                         CC = CC + 1
#                     elif call_rate == "CNC":
#                         CNC = CNC + 1                
#                     elif call_rate == "IC":
#                         IC = IC + 1
#                     else:
#                         INC = INC + 1
#                     break
#         else:
#             continue
                    
# print("Correct Calls: " + str(CC))
# print("Correct No Calls: " + str(CNC))
# print("Incorrect Calls: " + str(IC))
# print("Incorrect No Calls: " + str(INC))

# %%
players = pd.read_csv("Lakers.csv")
player_names = players['player'].tolist()
timestamps = []
CC = 0
CNC = 0
IC = 0
INC = 0
for data in gameData:
    times = data["l2m"] 
    #print(times)
    for time in times:
        timestamps = time['PCTime'][:5]
        time_left = int(timestamps[:2])*60 + int(timestamps[3:5])
        call_rate = time['CallRatingName']
        dp = time['DP']
        cp = time['CP']
        action = time['Comment']
        for player in player_names:
            if player == dp or dp == 'Lakers':
                if time_left <= 120 and time_left > 30:
                    print(timestamps, str(time_left) + ' secs', 'CP: ' + cp, 'DP: ' + dp, call_rate)
                    if call_rate == "CC":
                        CC = CC + 1
                    elif call_rate == "CNC":
                        CNC = CNC + 1                
                    elif call_rate == "IC":
                        IC = IC + 1
                    else:
                        INC = INC + 1
                    break
        else:
            continue
                    
print("Correct Calls: " + str(CC/len(laker_games)))
print("Correct No Calls: " + str(CNC/len(laker_games)))
print("Incorrect Calls: " + str(IC/len(laker_games)))
print("Incorrect No Calls: " + str(INC/len(laker_games)))
# Out:
# 01:57 117 secs CP: Josh Hart DP: LeBron James CNC
# 01:54 114 secs CP: Jusuf Nurkic DP: Lonnie Walker IV CNC
# 01:31 91 secs CP: Damian Lillard DP: Patrick Beverley CNC
# 01:29 89 secs CP: Jusuf Nurkic DP: Anthony Davis CNC
# 00:55 55 secs CP: Jerami Grant DP: LeBron James CNC
# 00:39 39 secs CP: Jusuf Nurkic DP: Lonnie Walker IV CNC
# 02:00 120 secs CP: Larry Nance Jr. DP: Austin Reaves CNC
# 01:59 119 secs CP: Devonte' Graham DP: Austin Reaves CNC
# 01:55 115 secs CP: Devonte' Graham DP: Anthony Davis CNC
# 01:55 115 secs CP: Trey Murphy III DP: Anthony Davis CNC
# 01:53 113 secs CP: Naji Marshall DP: LeBron James CNC
# 01:53 113 secs CP: Trey Murphy III DP: Lakers CC
# 01:43 103 secs CP: Zion Williamson DP: Lakers INC
# 01:42 102 secs CP: Larry Nance Jr. DP: LeBron James CC
# 01:27 87 secs CP: Larry Nance Jr. DP: Austin Reaves CC
# 01:13 73 secs CP: CJ McCollum DP: Patrick Beverley CNC
# 00:55 55 secs CP: Naji Marshall DP: LeBron James CNC
# ...

# %%
# players = pd.read_csv("Lakers.csv")
# player_names = players['player'].tolist()
# timestamps = []
# CC = 0
# CNC = 0
# IC = 0
# INC = 0
# for data in gameData:
#     times = data["l2m"] 
#     #print(times)
#     for time in times:
#         timestamps = time['PCTime'][:5]
#         time_left = int(timestamps[:2])*60 + int(timestamps[3:5])
#         call_rate = time['CallRatingName']
#         dp = time['DP']
#         cp = time['CP']
#         action = time['Comment']
#         for player in player_names:
#             if player == dp or dp == 'Lakers':
#                 if time_left <= 120 and time_left > 90:
#                     print(timestamps, str(time_left) + ' secs', 'CP: ' + cp, 'DP: ' + dp, call_rate)
#                     if call_rate == "CC":
#                         CC = CC + 1
#                     elif call_rate == "CNC":
#                         CNC = CNC + 1                
#                     elif call_rate == "IC":
#                         IC = IC + 1
#                     else:
#                         INC = INC + 1
#                     break
#         else:
#             continue
                    
# print("Correct Calls: " + str(CC/len(laker_games)))
# print("Correct No Calls: " + str(CNC/len(laker_games)))
# print("Incorrect Calls: " + str(IC/len(laker_games)))
# print("Incorrect No Calls: " + str(INC/len(laker_games)))

# %%
# timestamps = []
# CC = 0
# CNC = 0
# IC = 0
# INC = 0
# for data in gameData:
#     times = data["l2m"] 
#     #print(times)
#     for time in times:
#         timestamps = time['PCTime'][:5]
#         time_left = int(timestamps[:2])*60 + int(timestamps[3:5])
#         call_rate = time['CallRatingName']
#         dp = time['DP']
#         cp = time['CP']
#         for player in player_names:
#             if player == dp or dp == 'Lakers':
#                 if time_left <= 90 and time_left > 60:
#                     print(timestamps, str(time_left) + ' secs', 'CP: ' + cp, 'DP: ' + dp, call_rate)
#                     if call_rate == "CC":
#                         CC = CC + 1
#                     elif call_rate == "CNC":
#                         CNC = CNC + 1                
#                     elif call_rate == "IC":
#                         IC = IC + 1
#                     else:
#                         INC = INC + 1
#                     break
#         else:
#             continue
                    
# print("Correct Calls: " + str(CC))
# print("Correct No Calls: " + str(CNC))
# print("Incorrect Calls: " + str(IC))
# print("Incorrect No Calls: " + str(INC))

# %%
# players = pd.read_csv("Lakers.csv")
# player_names = players['player'].tolist()
# timestamps = []
# CC = 0
# CNC = 0
# IC = 0
# INC = 0
# for data in gameData:
#     times = data["l2m"] 
#     #print(times)
#     for time in times:
#         timestamps = time['PCTime'][:5]
#         time_left = int(timestamps[:2])*60 + int(timestamps[3:5])
#         call_rate = time['CallRatingName']
#         dp = time['DP']
#         cp = time['CP']
#         action = time['Comment']
#         for player in player_names:
#             if player == dp or dp == 'Lakers':
#                 if time_left <= 90 and time_left > 60:
#                     print(timestamps, str(time_left) + ' secs', 'CP: ' + cp, 'DP: ' + dp, call_rate)
#                     if call_rate == "CC":
#                         CC = CC + 1
#                     elif call_rate == "CNC":
#                         CNC = CNC + 1                
#                     elif call_rate == "IC":
#                         IC = IC + 1
#                     else:
#                         INC = INC + 1
#                     break
#         else:
#             continue
                    
# print("Correct Calls: " + str(CC/len(laker_games)))
# print("Correct No Calls: " + str(CNC/len(laker_games)))
# print("Incorrect Calls: " + str(IC/len(laker_games)))
# print("Incorrect No Calls: " + str(INC/len(laker_games)))

# %%
# timestamps = []
# CC = 0
# CNC = 0
# IC = 0
# INC = 0
# for data in gameData:
#     times = data["l2m"] 
#     #print(times)
#     for time in times:
#         timestamps = time['PCTime'][:5]
#         time_left = int(timestamps[:2])*60 + int(timestamps[3:5])
#         call_rate = time['CallRatingName']
#         dp = time['DP']
#         cp = time['CP']
#         for player in player_names:
#             if player == dp or dp == 'Lakers':
#                 if time_left <= 60 and time_left > 30:
#                     print(timestamps, str(time_left) + ' secs', 'CP: ' + cp, 'DP: ' + dp, call_rate)
#                     if call_rate == "CC":
#                         CC = CC + 1
#                     elif call_rate == "CNC":
#                         CNC = CNC + 1                
#                     elif call_rate == "IC":
#                         IC = IC + 1
#                     else:
#                         INC = INC + 1
#                     break
#         else:
#             continue
                    
# print("Correct Calls: " + str(CC))
# print("Correct No Calls: " + str(CNC))
# print("Incorrect Calls: " + str(IC))
# print("Incorrect No Calls: " + str(INC))

# %%
# players = pd.read_csv("Lakers.csv")
# player_names = players['player'].tolist()
# timestamps = []
# CC = 0
# CNC = 0
# IC = 0
# INC = 0
# for data in gameData:
#     times = data["l2m"] 
#     #print(times)
#     for time in times:
#         timestamps = time['PCTime'][:5]
#         time_left = int(timestamps[:2])*60 + int(timestamps[3:5])
#         call_rate = time['CallRatingName']
#         dp = time['DP']
#         cp = time['CP']
#         action = time['Comment']
#         for player in player_names:
#             if player == dp or dp == 'Lakers':
#                 if time_left <= 60 and time_left > 30:
#                     print(timestamps, str(time_left) + ' secs', 'CP: ' + cp, 'DP: ' + dp, call_rate)
#                     if call_rate == "CC":
#                         CC = CC + 1
#                     elif call_rate == "CNC":
#                         CNC = CNC + 1                
#                     elif call_rate == "IC":
#                         IC = IC + 1
#                     else:
#                         INC = INC + 1
#                     break
#         else:
#             continue
                    
# print("Correct Calls: " + str(CC/len(laker_games)))
# print("Correct No Calls: " + str(CNC/len(laker_games)))
# print("Incorrect Calls: " + str(IC/len(laker_games)))
# print("Incorrect No Calls: " + str(INC/len(laker_games)))

# %%
timestamps = []
CC = 0
CNC = 0
IC = 0
INC = 0
for data in gameData:
    times = data["l2m"] 
    #print(times)
    for time in times:
        timestamps = time['PCTime'][:5]
        time_left = int(timestamps[:2])*60 + int(timestamps[3:5])
        call_rate = time['CallRatingName']
        dp = time['DP']
        cp = time['CP']
        for player in player_names:
            if player == dp or dp == 'Lakers':
                if time_left <= 30:
                    print(timestamps, str(time_left) + ' secs', 'CP: ' + cp, 'DP: ' + dp, call_rate)
                    if call_rate == "CC":
                        CC = CC + 1
                    elif call_rate == "CNC":
                        CNC = CNC + 1                
                    elif call_rate == "IC":
                        IC = IC + 1
                    else:
                        INC = INC + 1
                    break
        else:
            continue
                    
print("Correct Calls: " + str(CC))
print("Correct No Calls: " + str(CNC))
print("Incorrect Calls: " + str(IC))
print("Incorrect No Calls: " + str(INC))
# Out:
# 00:21 21 secs CP: Jusuf Nurkic DP: Patrick Beverley CNC
# 00:16 16 secs CP: Damian Lillard DP: Lakers INC
# 00:11 11 secs CP: Jusuf Nurkic DP: LeBron James CNC
# 00:07 7 secs CP: Jerami Grant DP: Juan Toscano-Anderson CNC
# 00:02 2 secs CP: Damian Lillard DP: LeBron James CNC
# 00:01 1 secs CP: Damian Lillard DP: LeBron James CNC
# 00:20 20 secs CP: Zion Williamson DP: Lakers CNC
# 00:14 14 secs CP: Larry Nance Jr. DP: LeBron James CNC
# 00:07 7 secs CP: CJ McCollum DP: Patrick Beverley CNC
# 00:05 5 secs CP: Trey Murphy III DP: Lonnie Walker IV CNC
# 00:00 0 secs CP: Trey Murphy III DP: Matt Ryan CNC
# 00:05 5 secs CP: Larry Nance Jr. DP: Anthony Davis CNC
# 00:13 13 secs CP: Domantas Sabonis DP: Anthony Davis CNC
# 00:02 2 secs CP: Domantas Sabonis DP: Austin Reaves CNC
# 00:28 28 secs CP: Myles Turner DP: Lakers CNC
# 00:24 24 secs CP: Tyrese Haliburton DP: Lakers CNC
# 00:21 21 secs CP: Buddy Hield DP: LeBron James CNC
# 00:05 5 secs CP: Tyrese Haliburton DP: Lakers CNC
# ...

# %%
players = pd.read_csv("Lakers.csv")
player_names = players['player'].tolist()
timestamps = []
CC = 0
CNC = 0
IC = 0
INC = 0
for data in gameData:
    times = data["l2m"] 
    #print(times)
    for time in times:
        timestamps = time['PCTime'][:5]
        time_left = int(timestamps[:2])*60 + int(timestamps[3:5])
        call_rate = time['CallRatingName']
        dp = time['DP']
        cp = time['CP']
        action = time['Comment']
        for player in player_names:
            if player == dp or dp == 'Lakers':
                if time_left <= 30:
                    print(timestamps, str(time_left) + ' secs', 'CP: ' + cp, 'DP: ' + dp, call_rate)
                    if call_rate == "CC":
                        CC = CC + 1
                    elif call_rate == "CNC":
                        CNC = CNC + 1                
                    elif call_rate == "IC":
                        IC = IC + 1
                    else:
                        INC = INC + 1
                    break
        else:
            continue
                    
print("Correct Calls: " + str(CC/len(laker_games)))
print("Correct No Calls: " + str(CNC/len(laker_games)))
print("Incorrect Calls: " + str(IC/len(laker_games)))
print("Incorrect No Calls: " + str(INC/len(laker_games)))
# Out:
# 00:21 21 secs CP: Jusuf Nurkic DP: Patrick Beverley CNC
# 00:16 16 secs CP: Damian Lillard DP: Lakers INC
# 00:11 11 secs CP: Jusuf Nurkic DP: LeBron James CNC
# 00:07 7 secs CP: Jerami Grant DP: Juan Toscano-Anderson CNC
# 00:02 2 secs CP: Damian Lillard DP: LeBron James CNC
# 00:01 1 secs CP: Damian Lillard DP: LeBron James CNC
# 00:20 20 secs CP: Zion Williamson DP: Lakers CNC
# 00:14 14 secs CP: Larry Nance Jr. DP: LeBron James CNC
# 00:07 7 secs CP: CJ McCollum DP: Patrick Beverley CNC
# 00:05 5 secs CP: Trey Murphy III DP: Lonnie Walker IV CNC
# 00:00 0 secs CP: Trey Murphy III DP: Matt Ryan CNC
# 00:05 5 secs CP: Larry Nance Jr. DP: Anthony Davis CNC
# 00:13 13 secs CP: Domantas Sabonis DP: Anthony Davis CNC
# 00:02 2 secs CP: Domantas Sabonis DP: Austin Reaves CNC
# 00:28 28 secs CP: Myles Turner DP: Lakers CNC
# 00:24 24 secs CP: Tyrese Haliburton DP: Lakers CNC
# 00:21 21 secs CP: Buddy Hield DP: LeBron James CNC
# 00:05 5 secs CP: Tyrese Haliburton DP: Lakers CNC
# ...

# %%
players = pd.read_csv("Lakers.csv")
player_names = players['player'].tolist()
timestamps = []
CC = 0
CNC = 0
IC = 0
INC = 0
for data in gameData:
    times = data["l2m"] 
    #print(times)
    for time in times:
        timestamps = time['PCTime'][:5]
        time_left = int(timestamps[:2])*60 + int(timestamps[3:5])
        call_rate = time['CallRatingName']
        dp = time['DP']
        cp = time['CP']
        action = time['Comment']
        for player in player_names:
            if player == dp or dp == 'Lakers':
                if time_left <= 120:
                    print(timestamps, str(time_left) + ' secs', 'CP: ' + cp, 'DP: ' + dp, call_rate)
                    if call_rate == "CC":
                        CC = CC + 1
                    elif call_rate == "CNC":
                        CNC = CNC + 1                
                    elif call_rate == "IC":
                        IC = IC + 1
                    else:
                        INC = INC + 1
                    break
        else:
            continue
                    
print("Correct Calls: " + str(CC/len(laker_games)))
print("Correct No Calls: " + str(CNC/len(laker_games)))
print("Incorrect Calls: " + str(IC/len(laker_games)))
print("Incorrect No Calls: " + str(INC/len(laker_games)))
# Out:
# 01:57 117 secs CP: Josh Hart DP: LeBron James CNC
# 01:54 114 secs CP: Jusuf Nurkic DP: Lonnie Walker IV CNC
# 01:31 91 secs CP: Damian Lillard DP: Patrick Beverley CNC
# 01:29 89 secs CP: Jusuf Nurkic DP: Anthony Davis CNC
# 00:55 55 secs CP: Jerami Grant DP: LeBron James CNC
# 00:39 39 secs CP: Jusuf Nurkic DP: Lonnie Walker IV CNC
# 00:21 21 secs CP: Jusuf Nurkic DP: Patrick Beverley CNC
# 00:16 16 secs CP: Damian Lillard DP: Lakers INC
# 00:11 11 secs CP: Jusuf Nurkic DP: LeBron James CNC
# 00:07 7 secs CP: Jerami Grant DP: Juan Toscano-Anderson CNC
# 00:02 2 secs CP: Damian Lillard DP: LeBron James CNC
# 00:01 1 secs CP: Damian Lillard DP: LeBron James CNC
# 02:00 120 secs CP: Larry Nance Jr. DP: Austin Reaves CNC
# 01:59 119 secs CP: Devonte' Graham DP: Austin Reaves CNC
# 01:55 115 secs CP: Devonte' Graham DP: Anthony Davis CNC
# 01:55 115 secs CP: Trey Murphy III DP: Anthony Davis CNC
# 01:53 113 secs CP: Naji Marshall DP: LeBron James CNC
# ...

# %%
laker_l2m_loss = pd.read_csv("laker_l2m_loss.csv")
laker_loss = laker_l2m_loss['gameId'].tolist()
print(laker_loss)
# Out:
# [22200037, 22200183, 22200308, 22200382, 22200413, 22200492, 22200630, 22200655, 22200677, 22200749, 22200821]

# %%
laker_l2m_loss = pd.read_csv("laker_l2m_loss.csv")
laker_loss = laker_l2m_loss['gameId'].tolist()
laker_loss = ["00" + str(game) if str(game).isdigit() else str(game) for game in laker_loss]
gameData = []
for game in laker_loss:
    url = f'https://official.nba.com/l2m/json/{game}.json' 
    payload = ""
    response = requests.request("GET", url, data=payload) #headers=headers)
    if response.status_code == 200: 
        gameData.append(response.json())
    else:
        print(f'Request failed with status code: {response.status_code}')
        print(f'Error message: {response.text}')
print(gameData)
# Out:
# [{'game': [{'Home_team': 'Lakers', 'Away_team': 'Trail Blazers', 'GameId': '0022200037', 'HomeTeamScore': 104, 'VisitorTeamScore': 106, 'GameDate': '2022-10-23T15:30:00', 'HomeTeamId': 1610612747, 'AwayTeamId': 1610612757, 'Home_team_abbr': 'LAL', 'Away_team_abbr': 'POR', 'L2M_Comments': None, 'GameDateOut': 'October 23, 2022'}], 'stats': [{'stats_name': 'Calls', 'home': 1, 'away': 0}, {'stats_name': 'Errors in Favor', 'home': 3, 'away': 1}, {'stats_name': 'Possessions in Favor', 'home': 0, 'away': 0}], 'l2m': [{'PeriodName': 'Q4', 'PCTime': '01:57.2', 'ImposibleIndicator': 0, 'Comment': "Hart (POR) places his forearm to James' (LAL) side and marginal contact occurs contesting his driving shot attempt.", 'CallRatingName': 'CNC', 'CallType': 'Foul: Shooting', 'CP': 'Josh Hart', 'DP': 'LeBron James', 'Difficulty': 'Observable', 'VideolLink': '2147', 'Qualifier': None, 'posID': 1534, 'posStart': '02:16.3', 'posEnd': '01:56.3', 'posTeamId': 1610612747, 'teamIdInFavor': None, 'errorInFavo
# ...

# %%
players = pd.read_csv("Lakers.csv")
player_names = players['player'].tolist()
timestamps = []
CC = 0
CNC = 0
IC = 0
INC = 0
for data in gameData:
    times = data["l2m"] 
    #print(times)
    for time in times:
        timestamps = time['PCTime'][:5]
        time_left = int(timestamps[:2])*60 + int(timestamps[3:5])
        call_rate = time['CallRatingName']
        dp = time['DP']
        cp = time['CP']
        action = time['Comment']
        for player in player_names:
            if player == dp or dp == 'Lakers':
                if time_left <= 120 and time_left > 30:
                    print(timestamps, str(time_left) + ' secs', 'CP: ' + cp, 'DP: ' + dp, call_rate)
                    if call_rate == "CC":
                        CC = CC + 1
                    elif call_rate == "CNC":
                        CNC = CNC + 1                
                    elif call_rate == "IC":
                        IC = IC + 1
                    else:
                        INC = INC + 1
                    break
        else:
            continue
                    
print("Correct Calls: " + str(CC/len(laker_games)))
print("Correct No Calls: " + str(CNC/len(laker_games)))
print("Incorrect Calls: " + str(IC/len(laker_games)))
print("Incorrect No Calls: " + str(INC/len(laker_games)))
# Out:
# 01:57 117 secs CP: Josh Hart DP: LeBron James CNC
# 01:54 114 secs CP: Jusuf Nurkic DP: Lonnie Walker IV CNC
# 01:31 91 secs CP: Damian Lillard DP: Patrick Beverley CNC
# 01:29 89 secs CP: Jusuf Nurkic DP: Anthony Davis CNC
# 00:55 55 secs CP: Jerami Grant DP: LeBron James CNC
# 00:39 39 secs CP: Jusuf Nurkic DP: Lonnie Walker IV CNC
# 02:00 120 secs CP: Davion Mitchell DP: Lonnie Walker IV CNC
# 01:45 105 secs CP: Domantas Sabonis DP: Austin Reaves CNC
# 01:32 92 secs CP: Domantas Sabonis DP: Anthony Davis CNC
# 01:23 83 secs CP: Domantas Sabonis DP: Russell Westbrook CNC
# 01:22 82 secs CP: Harrison Barnes DP: Anthony Davis CNC
# 00:51 51 secs CP: Kevin Huerter DP: Lonnie Walker IV CNC
# 00:47 47 secs CP: Malik Monk DP: Patrick Beverley CNC
# 00:45 45 secs CP: Harrison Barnes DP: Anthony Davis CNC
# 00:32 32 secs CP: Domantas Sabonis DP: Anthony Davis CNC
# 00:31 31 secs CP: Harrison Barnes DP: Lonnie Walker IV CNC
# 01:55 115 secs CP: Tyrese Haliburton DP: Russell Westbrook CNC
# ...

# %%
# players = pd.read_csv("Lakers.csv")
# player_names = players['player'].tolist()
# timestamps = []
# CC = 0
# CNC = 0
# IC = 0
# INC = 0
# for data in gameData:
#     times = data["l2m"] 
#     #print(times)
#     for time in times:
#         timestamps = time['PCTime'][:5]
#         time_left = int(timestamps[:2])*60 + int(timestamps[3:5])
#         call_rate = time['CallRatingName']
#         dp = time['DP']
#         cp = time['CP']
#         action = time['Comment']
#         for player in player_names:
#             if player == dp or dp == 'Lakers':
#                 if time_left <= 120 and time_left > 90:
#                     print(timestamps, str(time_left) + ' secs', 'CP: ' + cp, 'DP: ' + dp, call_rate)
#                     if call_rate == "CC":
#                         CC = CC + 1
#                     elif call_rate == "CNC":
#                         CNC = CNC + 1                
#                     elif call_rate == "IC":
#                         IC = IC + 1
#                     else:
#                         INC = INC + 1
#                     break
#         else:
#             continue
                    
# print("Correct Calls: " + str(CC/len(laker_games)))
# print("Correct No Calls: " + str(CNC/len(laker_games)))
# print("Incorrect Calls: " + str(IC/len(laker_games)))
# print("Incorrect No Calls: " + str(INC/len(laker_games)))

# %%
# players = pd.read_csv("Lakers.csv")
# player_names = players['player'].tolist()
# timestamps = []
# CC = 0
# CNC = 0
# IC = 0
# INC = 0
# for data in gameData:
#     times = data["l2m"] 
#     #print(times)
#     for time in times:
#         timestamps = time['PCTime'][:5]
#         time_left = int(timestamps[:2])*60 + int(timestamps[3:5])
#         call_rate = time['CallRatingName']
#         dp = time['DP']
#         cp = time['CP']
#         action = time['Comment']
#         for player in player_names:
#             if player == dp or dp == 'Lakers':
#                 if time_left <= 90 and time_left > 60:
#                     print(timestamps, str(time_left) + ' secs', 'CP: ' + cp, 'DP: ' + dp, call_rate)
#                     if call_rate == "CC":
#                         CC = CC + 1
#                     elif call_rate == "CNC":
#                         CNC = CNC + 1                
#                     elif call_rate == "IC":
#                         IC = IC + 1
#                     else:
#                         INC = INC + 1
#                     break
#         else:
#             continue
                    
# print("Correct Calls: " + str(CC/len(laker_games)))
# print("Correct No Calls: " + str(CNC/len(laker_games)))
# print("Incorrect Calls: " + str(IC/len(laker_games)))
# print("Incorrect No Calls: " + str(INC/len(laker_games)))

# %%
# players = pd.read_csv("Lakers.csv")
# player_names = players['player'].tolist()
# timestamps = []
# CC = 0
# CNC = 0
# IC = 0
# INC = 0
# for data in gameData:
#     times = data["l2m"] 
#     #print(times)
#     for time in times:
#         timestamps = time['PCTime'][:5]
#         time_left = int(timestamps[:2])*60 + int(timestamps[3:5])
#         call_rate = time['CallRatingName']
#         dp = time['DP']
#         cp = time['CP']
#         action = time['Comment']
#         for player in player_names:
#             if player == dp or dp == 'Lakers':
#                 if time_left <= 60 and time_left > 30:
#                     print(timestamps, str(time_left) + ' secs', 'CP: ' + cp, 'DP: ' + dp, call_rate)
#                     if call_rate == "CC":
#                         CC = CC + 1
#                     elif call_rate == "CNC":
#                         CNC = CNC + 1                
#                     elif call_rate == "IC":
#                         IC = IC + 1
#                     else:
#                         INC = INC + 1
#                     break
#         else:
#             continue
                    
# print("Correct Calls: " + str(CC/len(laker_games)))
# print("Correct No Calls: " + str(CNC/len(laker_games)))
# print("Incorrect Calls: " + str(IC/len(laker_games)))
# print("Incorrect No Calls: " + str(INC/len(laker_games)))

# %%
players = pd.read_csv("Lakers.csv")
player_names = players['player'].tolist()
timestamps = []
CC = 0
CNC = 0
IC = 0
INC = 0
for data in gameData:
    times = data["l2m"] 
    #print(times)
    for time in times:
        timestamps = time['PCTime'][:5]
        time_left = int(timestamps[:2])*60 + int(timestamps[3:5])
        call_rate = time['CallRatingName']
        dp = time['DP']
        cp = time['CP']
        action = time['Comment']
        for player in player_names:
            if player == dp or dp == 'Lakers':
                if time_left <= 30:
                    print(timestamps, str(time_left) + ' secs', 'CP: ' + cp, 'DP: ' + dp, call_rate)
                    if call_rate == "CC":
                        CC = CC + 1
                    elif call_rate == "CNC":
                        CNC = CNC + 1                
                    elif call_rate == "IC":
                        IC = IC + 1
                    else:
                        INC = INC + 1
                    break
        else:
            continue
                    
print("Correct Calls: " + str(CC/len(laker_games)))
print("Correct No Calls: " + str(CNC/len(laker_games)))
print("Incorrect Calls: " + str(IC/len(laker_games)))
print("Incorrect No Calls: " + str(INC/len(laker_games)))
# Out:
# 00:21 21 secs CP: Jusuf Nurkic DP: Patrick Beverley CNC
# 00:16 16 secs CP: Damian Lillard DP: Lakers INC
# 00:11 11 secs CP: Jusuf Nurkic DP: LeBron James CNC
# 00:07 7 secs CP: Jerami Grant DP: Juan Toscano-Anderson CNC
# 00:02 2 secs CP: Damian Lillard DP: LeBron James CNC
# 00:01 1 secs CP: Damian Lillard DP: LeBron James CNC
# 00:13 13 secs CP: Domantas Sabonis DP: Anthony Davis CNC
# 00:02 2 secs CP: Domantas Sabonis DP: Austin Reaves CNC
# 00:28 28 secs CP: Myles Turner DP: Lakers CNC
# 00:24 24 secs CP: Tyrese Haliburton DP: Lakers CNC
# 00:21 21 secs CP: Buddy Hield DP: LeBron James CNC
# 00:05 5 secs CP: Tyrese Haliburton DP: Lakers CNC
# 00:00 0 secs CP: Pacers DP: Lakers CC
# 00:29 29 secs CP: Matisse Thybulle DP: Patrick Beverley CNC
# 00:27 27 secs CP: Shake Milton DP: Anthony Davis CC
# 00:11 11 secs CP: Tobias Harris DP: Lakers CNC
# 00:10 10 secs CP: Patrick Beverley DP: Lakers INC
# 00:09 9 secs CP: Matisse Thybulle DP: Austin Reaves CC
# ...
